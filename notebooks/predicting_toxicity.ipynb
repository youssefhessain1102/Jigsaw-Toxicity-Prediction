# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))  # or the path to your project root
from predict import PredictService

# %%
import os
os.chdir(r"D:\python_files\Jigsaw_Toxicity_Prediction")

# %%
import yaml
with open("config.yaml", "r") as file:
    config = yaml.safe_load(file)

# %%
config['paths']['best_model_name']
# Out:
# 'best_model.pt'

# %%
predict_service = PredictService(config=config)
text = "I love Capitalism"

output = predict_service.predict(text)
output
# Out:
# 2026-04-01 20:41:52 | INFO     | predict | Model loaded from ./models\best_model.pt | Running on: cpu
# 2026-04-01 20:41:52 | INFO     | predict | Thresholds loaded: {'toxic': 0.68, 'severe_toxic': 0.84, 'obscene': 0.64, 'threat': 0.95, 'insult': 0.83, 'identity_hate': 0.78}
# {'toxic': 0,
#  'severe_toxic': 0,
#  'obscene': 0,
#  'threat': 0,
#  'insult': 0,
#  'identity_hate': 0}
